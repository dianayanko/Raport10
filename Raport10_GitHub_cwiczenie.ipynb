# %% [markdown]
# <a href="https://colab.research.google.com/github/dianayanko/Raport10/blob/main/Raport10_GitHub_cwiczenie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://raw.githubusercontent.com/DrMichalWojcik/Raport10/refs/heads/main/googleplaystore.csv -O google_wget.csv
# !wget https://raw.githubusercontent.com/dianayanko/Raport10/refs/heads/main/AppleStore.csv -O apple_wget.csv

from csv import reader
google = list(reader(open('google_wget.csv')))
apple = list(reader(open('apple_wget.csv')))

apple = apple[1:]
google = google[1:]

apple_header = apple[0]
google_header = google[0]
# Out:
# --2025-06-26 18:04:03--  https://raw.githubusercontent.com/DrMichalWojcik/Raport10/refs/heads/main/googleplaystore.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1349314 (1.3M) [text/plain]
# Saving to: ‘google_wget.csv’
#
# google_wget.csv     100%[===================>]   1.29M  --.-KB/s    in 0.09s
#
# 2025-06-26 18:04:03 (13.8 MB/s) - ‘google_wget.csv’ saved [1349314/1349314]
#
# --2025-06-26 18:04:03--  https://raw.githubusercontent.com/dianayanko/Raport10/refs/heads/main/AppleStore.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 837657 (818K) [text/plain]
# Saving to: ‘apple_wget.csv’
#
# apple_wget.csv      100%[===================>] 818.02K  --.-KB/s    in 0.08s
#
# 2025-06-26 18:04:03 (10.6 MB/s) - ‘apple_wget.csv’ saved [837657/837657]

# %%
def only_good_length_rows(dataset, header):
  good_length_rows = []
  for row in dataset:
    if len(row) == len(header):
      good_length_rows.append(row)
  return good_length_rows

def remove_duplicates(dataset, index_name, index_reviews):
  reviews_max = {}
  for app in dataset:
    name = app[index_name]
    n_reviews = float(app[index_reviews])
    if name in reviews_max and reviews_max[name] < n_reviews:
        reviews_max[name] = n_reviews
    elif name not in reviews_max:
        reviews_max[name] = n_reviews

  clean = []
  already_added = []
  for app in dataset:
    name = app[index_name]
    n_reviews = float(app[index_reviews])

    if (reviews_max[name] == n_reviews) and (name not in already_added):
        clean.append(app)
        already_added.append(name)
  return clean

def is_english(string):
    non_ascii = 0
    for character in string:
        if ord(character) > 127:
            non_ascii += 1
    if non_ascii > 3:
        return False
    else:
        return True

def remove_non_english_apps(dataset, index):
  english_dataset = []
  for row in dataset:
    name = row[index]
    if is_english(name):
      english_dataset.append(row)
  return english_dataset

def only_free_apps(dataset, index):
  free_dataset = []
  for row in dataset:
    price = row[index]
    if price == '0' or price == '0.0':
      free_dataset.append(row)
  return free_dataset

def google_ready():
  google_step2 = google
  google_step3 = only_good_length_rows(google_step2, google_header)
  google_step5 = remove_duplicates(google_step3, 0, 3)
  google_step7 = remove_non_english_apps(google_step5, 0)
  google_English_free = only_free_apps(google_step7, 7)
  return google_English_free

def apple_ready():
  apple_step2 = apple
  apple_step3 = only_good_length_rows(apple_step2, apple_header)
  apple_step5 = apple_step3 # nothing to do
  apple_step7 = remove_non_english_apps(apple_step5, 1)
  apple_English_free = only_free_apps(apple_step7, 4)
  return apple_English_free

def verify_ready():
  google_OK = google_ready() == free_google
  apple_OK = apple_ready() == free_apple
  print("google:", google_OK, "apple:", apple_OK)
  return google_OK and apple_OK

verify_ready()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5e75ad5a31dc> in <cell line: 0>()
#      75   return google_OK and apple_OK
#      76
# ---> 77 verify_ready()
#
# <ipython-input-2-5e75ad5a31dc> in verify_ready()
#      70
#      71 def verify_ready():
# ---> 72   google_OK = google_ready() == free_google
#      73   apple_OK = apple_ready() == free_apple
#      74   print("google:", google_OK, "apple:", apple_OK)
#
# NameError: name 'free_google' is not defined

# %%
def explore_data(dataset, start, end, rows_and_columns=False):
    dataset_slice = dataset[start:end]
    for row in dataset_slice:
        print(row)
        print('\n') # adds a new (empty) line after each row
    if rows_and_columns:
      print('Number of rows:', len(dataset))
      print('Number of columns:', len(dataset[0]))

explore_data(google, 0, 3, True)

# %%
def unich_step12_2():
  unich = '''
  Social Networking : 71548.34905660378
  Photo & Video : 28441.54375
  Games : 22788.6696905016
  Music : 57326.530303030304
  Reference : 74942.11111111111
  Health & Fitness : 23298.015384615384
  Weather : 52279.892857142855
  Utilities : 18684.456790123455
  Travel : 28243.8
  Shopping : 26919.690476190477
  News : 21248.023255813954
  Navigation : 86090.33333333333
  Lifestyle : 16485.764705882353
  Entertainment : 14029.830708661417
  Food & Drink : 33333.92307692308
  Sports : 23008.898550724636
  Book : 39758.5
  Finance : 31467.944444444445
  Education : 7003.983050847458
  Productivity : 21028.410714285714
  Business : 7491.117647058823
  Catalogs : 4004.0
  Medical : 612.0
  '''
  dct = {}
  for line in unich.strip().splitlines():
    parsed = line.split(':')
    genre = parsed[0].strip()
    average = float(parsed[1].strip())
    average = int(round(average, 0))
    dct[genre] = average
  return sorted(dct.items(), key=lambda x: x[1], reverse=True)

def unich_step13_2():
  unich = '''
  ART_AND_DESIGN : 1986335.0877192982
  AUTO_AND_VEHICLES : 647317.8170731707
  BEAUTY : 513151.88679245283
  BOOKS_AND_REFERENCE : 8767811.894736841
  BUSINESS : 1712290.1474201474
  COMICS : 817657.2727272727
  COMMUNICATION : 38456119.167247385
  DATING : 854028.8303030303
  EDUCATION : 1833495.145631068
  ENTERTAINMENT : 11640705.88235294
  EVENTS : 253542.22222222222
  FINANCE : 1387692.475609756
  FOOD_AND_DRINK : 1924897.7363636363
  HEALTH_AND_FITNESS : 4188821.9853479853
  HOUSE_AND_HOME : 1331540.5616438356
  LIBRARIES_AND_DEMO : 638503.734939759
  LIFESTYLE : 1437816.2687861272
  GAME : 15588015.603248259
  FAMILY : 3695641.8198090694
  MEDICAL : 120550.61980830671
  SOCIAL : 23253652.127118643
  SHOPPING : 7036877.311557789
  PHOTOGRAPHY : 17840110.40229885
  SPORTS : 3638640.1428571427
  TRAVEL_AND_LOCAL : 13984077.710144928
  TOOLS : 10801391.298666667
  PERSONALIZATION : 5201482.6122448975
  PRODUCTIVITY : 16787331.344927534
  PARENTING : 542603.6206896552
  WEATHER : 5074486.197183099
  VIDEO_PLAYERS : 24727872.452830188
  NEWS_AND_MAGAZINES : 9549178.467741935
  MAPS_AND_NAVIGATION : 4056941.7741935486
  '''
  dct = {}
  for line in unich.strip().splitlines():
    parsed = line.split(':')
    genre = parsed[0].strip()
    average = float(parsed[1].strip())
    average = int(round(average, 0))
    dct[genre] = average
  return sorted(dct.items(), key=lambda x: x[1], reverse=True)


print(unich_step12_2())
print('\n')
print(unich_step13_2())

def verify_step12_2():
  return unich_step12_2() == step12_2

def verify_step13_2():
  return unich_step13_2() == step13_2

verify_step12_2()
verify_step13_2()
